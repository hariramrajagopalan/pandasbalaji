# %%
import pandas as pd

# %%
df = pd.read_csv("/Users/dr.brindha/Downloads/Automobile.csv")

# %%
df.head()
# Out:
#    symboling  normalized_losses         make fuel_type aspiration  \
# 0          3                168  alfa-romero       gas        std
# 1          3                168  alfa-romero       gas        std
# 2          1                168  alfa-romero       gas        std
# 3          2                164         audi       gas        std
# 4          2                164         audi       gas        std
#
#   number_of_doors   body_style drive_wheels engine_location  wheel_base  ...  \
# 0             two  convertible          rwd           front        88.6  ...
# 1             two  convertible          rwd           front        88.6  ...
# 2             two    hatchback          rwd           front        94.5  ...
# 3            four        sedan          fwd           front        99.8  ...
# 4            four        sedan          4wd           front        99.4  ...
#
#    engine_size  fuel_system  bore  stroke compression_ratio horsepower  \
# ...

# %%
df.isnull()
# Out:
#      symboling  normalized_losses   make  fuel_type  aspiration  \
# 0        False              False  False      False       False
# 1        False              False  False      False       False
# 2        False              False  False      False       False
# 3        False              False  False      False       False
# 4        False              False  False      False       False
# ..         ...                ...    ...        ...         ...
# 196      False              False  False      False       False
# 197      False              False  False      False       False
# 198      False              False  False      False       False
# 199      False              False  False      False       False
# 200      False              False  False      False       False
#
#      number_of_doors  body_style  drive_wheels  engine_location  wheel_base  \
# 0              False       False         False            False       False
# ...

# %%
len(df)
# Out:
# 201

# %%
df.dropna()
# Out:
#      symboling  normalized_losses         make fuel_type aspiration  \
# 0            3                168  alfa-romero       gas        std
# 1            3                168  alfa-romero       gas        std
# 2            1                168  alfa-romero       gas        std
# 3            2                164         audi       gas        std
# 4            2                164         audi       gas        std
# ..         ...                ...          ...       ...        ...
# 196         -1                 95        volvo       gas        std
# 197         -1                 95        volvo       gas      turbo
# 198         -1                 95        volvo       gas        std
# 199         -1                 95        volvo    diesel      turbo
# 200         -1                 95        volvo       gas      turbo
#
#     number_of_doors   body_style drive_wheels engine_location  wheel_base  \
# 0               two  convertible          rwd           front        88.6
# ...

# %%
df.isnull().sum()
# Out:
# symboling              0
# normalized_losses      0
# make                   0
# fuel_type              0
# aspiration             0
# number_of_doors        0
# body_style             0
# drive_wheels           0
# engine_location        0
# wheel_base             0
# length                 0
# width                  0
# height                 0
# curb_weight            0
# engine_type            0
# number_of_cylinders    0
# engine_size            0
# fuel_system            0
# bore                   0
# stroke                 0
# compression_ratio      0
# horsepower             0
# peak_rpm               0
# city_mpg               0
# highway_mpg            0
# price                  0
# dtype: int64

# %%
df.shape
# Out:
# (201, 26)

# %%
df.to_csv("/Users/dr.brindha/Downloads/Automobile_without_null_values.csv")

# %%
df.head()
# Out:
#    symboling  normalized_losses         make fuel_type aspiration  \
# 0          3                168  alfa-romero       gas        std
# 1          3                168  alfa-romero       gas        std
# 2          1                168  alfa-romero       gas        std
# 3          2                164         audi       gas        std
# 4          2                164         audi       gas        std
#
#   number_of_doors   body_style drive_wheels engine_location  wheel_base  ...  \
# 0             two  convertible          rwd           front        88.6  ...
# 1             two  convertible          rwd           front        88.6  ...
# 2             two    hatchback          rwd           front        94.5  ...
# 3            four        sedan          fwd           front        99.8  ...
# 4            four        sedan          4wd           front        99.4  ...
#
#    engine_size  fuel_system  bore  stroke compression_ratio horsepower  \
# ...

# %%
df.iloc[:,:]
# Out:
#      symboling  normalized_losses         make fuel_type aspiration  \
# 0            3                168  alfa-romero       gas        std
# 1            3                168  alfa-romero       gas        std
# 2            1                168  alfa-romero       gas        std
# 3            2                164         audi       gas        std
# 4            2                164         audi       gas        std
# ..         ...                ...          ...       ...        ...
# 196         -1                 95        volvo       gas        std
# 197         -1                 95        volvo       gas      turbo
# 198         -1                 95        volvo       gas        std
# 199         -1                 95        volvo    diesel      turbo
# 200         -1                 95        volvo       gas      turbo
#
#     number_of_doors   body_style drive_wheels engine_location  wheel_base  \
# 0               two  convertible          rwd           front        88.6
# ...

# %%
df.iloc[:5,:]
# Out:
#    symboling  normalized_losses         make fuel_type aspiration  \
# 0          3                168  alfa-romero       gas        std
# 1          3                168  alfa-romero       gas        std
# 2          1                168  alfa-romero       gas        std
# 3          2                164         audi       gas        std
# 4          2                164         audi       gas        std
#
#   number_of_doors   body_style drive_wheels engine_location  wheel_base  ...  \
# 0             two  convertible          rwd           front        88.6  ...
# 1             two  convertible          rwd           front        88.6  ...
# 2             two    hatchback          rwd           front        94.5  ...
# 3            four        sedan          fwd           front        99.8  ...
# 4            four        sedan          4wd           front        99.4  ...
#
#    engine_size  fuel_system  bore  stroke compression_ratio horsepower  \
# ...

# %%
df.iloc[:,:5]
# Out:
#      symboling  normalized_losses         make fuel_type aspiration
# 0            3                168  alfa-romero       gas        std
# 1            3                168  alfa-romero       gas        std
# 2            1                168  alfa-romero       gas        std
# 3            2                164         audi       gas        std
# 4            2                164         audi       gas        std
# ..         ...                ...          ...       ...        ...
# 196         -1                 95        volvo       gas        std
# 197         -1                 95        volvo       gas      turbo
# 198         -1                 95        volvo       gas        std
# 199         -1                 95        volvo    diesel      turbo
# 200         -1                 95        volvo       gas      turbo
#
# [201 rows x 5 columns]

# %%
df.iloc[:5,:5]
# Out:
#    symboling  normalized_losses         make fuel_type aspiration
# 0          3                168  alfa-romero       gas        std
# 1          3                168  alfa-romero       gas        std
# 2          1                168  alfa-romero       gas        std
# 3          2                164         audi       gas        std
# 4          2                164         audi       gas        std

# %%
df.iloc[5:,5:]
# Out:
#     number_of_doors body_style drive_wheels engine_location  wheel_base  \
# 5               two      sedan          fwd           front        99.8
# 6              four      sedan          fwd           front       105.8
# 7              four      wagon          fwd           front       105.8
# 8              four      sedan          fwd           front       105.8
# 9               two      sedan          rwd           front       101.2
# ..              ...        ...          ...             ...         ...
# 196            four      sedan          rwd           front       109.1
# 197            four      sedan          rwd           front       109.1
# 198            four      sedan          rwd           front       109.1
# 199            four      sedan          rwd           front       109.1
# 200            four      sedan          rwd           front       109.1
#
#      length  width  height  curb_weight engine_type  ... engine_size  \
# ...

# %%
df.iloc[:-5, :-5]
# Out:
#      symboling  normalized_losses         make fuel_type aspiration  \
# 0            3                168  alfa-romero       gas        std
# 1            3                168  alfa-romero       gas        std
# 2            1                168  alfa-romero       gas        std
# 3            2                164         audi       gas        std
# 4            2                164         audi       gas        std
# ..         ...                ...          ...       ...        ...
# 191         -1                 74        volvo       gas        std
# 192         -2                103        volvo       gas        std
# 193         -1                 74        volvo       gas        std
# 194         -2                103        volvo       gas      turbo
# 195         -1                 74        volvo       gas      turbo
#
#     number_of_doors   body_style drive_wheels engine_location  wheel_base  \
# 0               two  convertible          rwd           front        88.6
# ...

# %%
df.iloc[-5:, -5:]
# Out:
#      horsepower  peak_rpm  city_mpg  highway_mpg  price
# 196         114      5400        23           28  16845
# 197         160      5300        19           25  19045
# 198         134      5500        18           23  21485
# 199         106      4800        26           27  22470
# 200         114      5400        19           25  22625

# %%
df.head()
# Out:
#    symboling  normalized_losses         make fuel_type aspiration  \
# 0          3                168  alfa-romero       gas        std
# 1          3                168  alfa-romero       gas        std
# 2          1                168  alfa-romero       gas        std
# 3          2                164         audi       gas        std
# 4          2                164         audi       gas        std
#
#   number_of_doors   body_style drive_wheels engine_location  wheel_base  ...  \
# 0             two  convertible          rwd           front        88.6  ...
# 1             two  convertible          rwd           front        88.6  ...
# 2             two    hatchback          rwd           front        94.5  ...
# 3            four        sedan          fwd           front        99.8  ...
# 4            four        sedan          4wd           front        99.4  ...
#
#    engine_size  fuel_system  bore  stroke compression_ratio horsepower  \
# ...

# %%
df.loc[:5, :]
# Out:
#    symboling  normalized_losses         make fuel_type aspiration  \
# 0          3                168  alfa-romero       gas        std
# 1          3                168  alfa-romero       gas        std
# 2          1                168  alfa-romero       gas        std
# 3          2                164         audi       gas        std
# 4          2                164         audi       gas        std
# 5          2                161         audi       gas        std
#
#   number_of_doors   body_style drive_wheels engine_location  wheel_base  ...  \
# 0             two  convertible          rwd           front        88.6  ...
# 1             two  convertible          rwd           front        88.6  ...
# 2             two    hatchback          rwd           front        94.5  ...
# 3            four        sedan          fwd           front        99.8  ...
# 4            four        sedan          4wd           front        99.4  ...
# ...

# %%
df.loc[:5, :"number_of_doors"]
# Out:
#    symboling  normalized_losses         make fuel_type aspiration  \
# 0          3                168  alfa-romero       gas        std
# 1          3                168  alfa-romero       gas        std
# 2          1                168  alfa-romero       gas        std
# 3          2                164         audi       gas        std
# 4          2                164         audi       gas        std
# 5          2                161         audi       gas        std
#
#   number_of_doors
# 0             two
# 1             two
# 2             two
# 3            four
# 4            four
# 5             two

# %%
df.iloc[::2, ::2]
# Out:
#      symboling         make aspiration   body_style engine_location  length  \
# 0            3  alfa-romero        std  convertible           front   168.8
# 2            1  alfa-romero        std    hatchback           front   171.2
# 4            2         audi        std        sedan           front   176.6
# 6            1         audi        std        sedan           front   192.7
# 8            1         audi      turbo        sedan           front   192.7
# ..         ...          ...        ...          ...             ...     ...
# 192         -2        volvo        std        sedan           front   188.8
# 194         -2        volvo      turbo        sedan           front   188.8
# 196         -1        volvo        std        sedan           front   188.8
# 198         -1        volvo        std        sedan           front   188.8
# 200         -1        volvo      turbo        sedan           front   188.8
#
# ...

# %%
df.iloc[0:12:2, 0:25:3]
# Out:
#     symboling fuel_type   body_style  wheel_base  height number_of_cylinders  \
# 0           3       gas  convertible        88.6    48.8                four
# 2           1       gas    hatchback        94.5    52.4                 six
# 4           2       gas        sedan        99.4    54.3                five
# 6           1       gas        sedan       105.8    55.7                five
# 8           1       gas        sedan       105.8    55.9                five
# 10          0       gas        sedan       101.2    54.3                four
#
#     bore  horsepower  highway_mpg
# 0   3.47         111           27
# 2   2.68         154           26
# 4   3.19         115           22
# 6   3.19         110           25
# 8   3.13         140           20
# 10  3.50         101           29

# %%
df.loc[0:12:2, "symboling":"highway_mpg":3]
# Out:
#     symboling fuel_type   body_style  wheel_base  height number_of_cylinders  \
# 0           3       gas  convertible        88.6    48.8                four
# 2           1       gas    hatchback        94.5    52.4                 six
# 4           2       gas        sedan        99.4    54.3                five
# 6           1       gas        sedan       105.8    55.7                five
# 8           1       gas        sedan       105.8    55.9                five
# 10          0       gas        sedan       101.2    54.3                four
# 12          0       gas        sedan       101.2    54.3                 six
#
#     bore  horsepower  highway_mpg
# 0   3.47         111           27
# 2   2.68         154           26
# 4   3.19         115           22
# 6   3.19         110           25
# 8   3.13         140           20
# 10  3.50         101           29
# 12  3.31         121           28

# %%
df[df["height"]==54.3]
# Out:
#      symboling  normalized_losses    make fuel_type aspiration  \
# 3            2                164    audi       gas        std
# 4            2                164    audi       gas        std
# 9            2                192     bmw       gas        std
# 10           0                192     bmw       gas        std
# 11           0                188     bmw       gas        std
# 12           0                188     bmw       gas        std
# 140          0                102  subaru       gas        std
# 141          0                102  subaru       gas      turbo
#
#     number_of_doors body_style drive_wheels engine_location  wheel_base  ...  \
# 3              four      sedan          fwd           front        99.8  ...
# 4              four      sedan          4wd           front        99.4  ...
# 9               two      sedan          rwd           front       101.2  ...
# 10             four      sedan          rwd           front       101.2  ...
# ...

# %%
df[df["height"]==54.3]["height"]
# Out:
# 3      54.3
# 4      54.3
# 9      54.3
# 10     54.3
# 11     54.3
# 12     54.3
# 140    54.3
# 141    54.3
# Name: height, dtype: float64

# %%
df[df["height"]==54.3].iloc[:100:1,::1]
# Out:
#      symboling  normalized_losses    make fuel_type aspiration  \
# 3            2                164    audi       gas        std
# 4            2                164    audi       gas        std
# 9            2                192     bmw       gas        std
# 10           0                192     bmw       gas        std
# 11           0                188     bmw       gas        std
# 12           0                188     bmw       gas        std
# 140          0                102  subaru       gas        std
# 141          0                102  subaru       gas      turbo
#
#     number_of_doors body_style drive_wheels engine_location  wheel_base  ...  \
# 3              four      sedan          fwd           front        99.8  ...
# 4              four      sedan          4wd           front        99.4  ...
# 9               two      sedan          rwd           front       101.2  ...
# 10             four      sedan          rwd           front       101.2  ...
# ...

# %%
(df.iloc[:100:,::1])[df["height"]==54.3]
# Out:
# /var/folders/2l/8s8fysnx6pd92mqmtl6n1fg00000gn/T/ipykernel_42415/3604758168.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   (df.iloc[:100:,::1])[df["height"]==54.3]
#     symboling  normalized_losses  make fuel_type aspiration number_of_doors  \
# 3           2                164  audi       gas        std            four
# 4           2                164  audi       gas        std            four
# 9           2                192   bmw       gas        std             two
# 10          0                192   bmw       gas        std            four
# 11          0                188   bmw       gas        std             two
# 12          0                188   bmw       gas        std            four
#
#    body_style drive_wheels engine_location  wheel_base  ...  engine_size  \
# 3       sedan          fwd           front        99.8  ...          109
# 4       sedan          4wd           front        99.4  ...          136
# ...

# %%
df_make = df[df["height"]==54.3].iloc[:100:2,::1]["make"]

# %%
df_height = df[df["height"]==54.3].iloc[:100:2,::1]["height"]

# %%
jsondf = pd.DataFrame({"a":df_make, "b":df_height})

# %%
ajson = jsondf.to_json()

# %%
ajson
# Out:
# '{"a":{"3":"audi","9":"bmw","11":"bmw","140":"subaru"},"b":{"3":54.3,"9":54.3,"11":54.3,"140":54.3}}'
